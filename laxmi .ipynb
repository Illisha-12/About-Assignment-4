# %%
from IPython.display import Image
Image('http://www.mysqltutorial.org/wp-content/uploads/2019/09/Python-MySQL.png')

# %%
pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 4.5MB 866kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.4MB 448kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# For mysql connector

import mysql.connector
mydb = mysql.connector.connect(host = '127.0.0.1', database= 'mysql', user = 'root',password = 'waiwai3232')

print(mydb)

# %%
pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#for PYMYSQL

import pymysql
pymysql= pymysql.connect(host='127.0.0.1',database='mysql',user='root',password='waiwai3232')
print (pymysql)

# %%
pip install tweepy
# Out:
# ...
#      |████████████████████████████████| 153kB 1.8MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy 

# For OAUTH we used Consumer keys and access tokens
Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

# for OAuth process, the Keys and tokens are uses
auth = tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)

# for setting the access token and access token secret
auth.set_access_token(Access_token, Access_token_Secret)

# creating the object using authentication
api = tweepy.API(auth)

api.update_status('I Love this World')
# Out:
# Status(_api=<tweepy.api.API object at 0x1096e3080>, _json={'created_at': 'Fri Nov 15 14:24:45 +0000 2019', 'id': 1195346907582873602, 'id_str': '1195346907582873602', 'text': 'I Love this World', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://placeholder.place" rel="nofollow">INFO 5717</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1192814806681735176, 'id_str': '1192814806681735176', 'name': 'Laxmi', 'screen_name': 'Laxmi59550885', 'location': 'Houston, TX', 'description': 'Love this world', 'url': 'https://t.co/7IDoW8Ah9W', 'entities': {'url': {'urls': [{'url': 'https://t.co/7IDoW8Ah9W', 'expanded_url': 'https://twitter.com', 'display_url': 'twitter.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'lis
# ...

# %%
import tweepy 

# For OAUTH we used Consumer keys and access tokens
Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

# for OAuth process, the Keys and tokens are uses
auth = tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)

# for setting the access token and access token secret
auth.set_access_token(Access_token, Access_token_Secret)

# creating the object using authentication
api = tweepy.API(auth)

api.update_status('I love python ')

user = api.get_user("Laxmi")
print ("User details:")
print(user.name)
print(user.description)
print(user.location)
print(user.followers)
print(user.friends)
print(user.status)
print(user.url)
# Out:
# User details:
# Laxmi
# New York Times bestselling author | Claim your FREE book ➡️ https://t.co/IA1UhyuGyk | INSTA ➡️ https://t.co/pAaExPdTfQ
# London
# ...

# %%
# to create a database

import mysql.connector

mydatabase = mysql.connector.connect(
     host= "127.0.0.1", 
     user= "root",
     password= "waiwai3232")

cursor = mydatabase.cursor()
cursor.execute("CREATE DATABASE MyNewDatabase")

cursor.execute("SHOW DATABASES")

for y in cursor:
    print(y)
# Out:
# ('DatabaseName',)
# ('information_schema',)
# ('MyNewDatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('user',)

# %%
#connecting the database with "MyNewDatabase"
import mysql.connector

mydatabase = mysql.connector.connect(
     host= "127.0.0.1", 
     user= "root",
     password= "waiwai3232",
     database= "MyNewDatabase")

# now create the Table Userinformation

cursor = mydatabase.cursor()
cursor.execute("CREATE TABLE Userinformation(ScreenName varchar(150),UserName varchar(50),Userlocation varchar(50),UserDescroption varchar(150),FollowerNumber int, FriendNumber int, StatusNumber int, UserURL varchar(100))")

cursor.execute("SHOW TABLES")

for Y in cursor:
    print(Y)
# Out:
# ('Userinformation',)

# %% [markdown]
# # Question 1.1

# %%
# SQL ststement to insert user information

import mysql.connector

mydatabase = mysql.connector.connect(
     host= "127.0.0.1", 
     user= "root",
     password= "waiwai3232",
     database= "MyNewDatabase")

cursor = mydatabase.cursor()

# inserting the single row

sql_query = "INSERT INTO Userinformation (ScreenName, UserName, Userlocation, UserDescroption, FollowerNumber, FriendNumber, StatusNumber, UserURL) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
value = ("Laxmi59550885", "Laxmi","Houston","love this world", "0", "0", "5", "https://t.co/7IDoW8Ah9W")
cursor.execute(sql_query, value)

mydatabase.commit()
print(cursor.rowcount, value)
# Out:
# 1 ('Laxmi59550885', 'Laxmi', 'Houston', 'love this world', '0', '0', '5', 'https://t.co/7IDoW8Ah9W')

# %% [markdown]
# # Question 1.2

# %%
 #SQL ststement to insert user information

import mysql.connector

mydatabase = mysql.connector.connect(
     host= "127.0.0.1", 
     user= "root",
     password= "waiwai3232",
     database= "MyNewDatabase")

cursor = mydatabase.cursor()

# inserting the multiple rows

mysql_query = "INSERT INTO Userinformation (ScreenName, UserName, Userlocation, UserDescroption, FollowerNumber, FriendNumber, StatusNumber, UserURL) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"

value =[
    ("Ashok59550880", "Ashok", "Houston", "love", "10", "20", "15", "https://t.co/7IDoW8Ah9W"),
    ("Uma59550890", "Uma", "Houston", "I like Houston","20", "30","25", "https://t.co/7IDoW8Ah9W"),
    ("Illisha59550895", "Illisha", "Houston", "I live in Houston", "10", "20","10", "https://t.co/7IDoW8Ah9W"),
    ("Mira5955082", "Mira", "Houston", "Lovely weather", "5", "10", "15", "https://t.co/7IDoW8Ah9W"),
    ("Sunder5955083", "Sunder","Texas", "Weather is bad in Texas","55","100","10","https://t.co/7IDoW8Ah9W"),
    ("Vaida5955084", "Vaida", "Irving", "Delicious food at Irving", "19","40","50","https://t.co/7IDoW8Ah9W"),
    ("Suren5955085", "Suren", "Carollton", "Home sweet home", "90","29","10", "https://t.co/7IDoW8Ah9W"),
    ("Sana5955086", "Sana", "Austin", "Chill Austin","70", "17","20", "https://t.co/7IDoW8Ah9W"),
    ("Krish5955087", "Krish", "Dallas", "Today in Dallas", "30","40","10", "https://t.co/7IDoW8Ah9W"),
    ("Ravi5955088", "Ravi", "Denton", "UNT at Denton", "99", "100", "10", "https://t.co/7IDoW8Ah9W")
]
    
cursor.executemany(mysql_query, value)
mydatabase.commit()
print(cursor.rowcount, value)

# getting users information and their ID 

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Uma59550890", "Uma")
cursor.execute(mysql, value)
mydatabase.commit()
print( "1 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Ravi5955088", "Ravi")
cursor.execute(mysql, value)
mydatabase.commit()
print( "2 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Ashok59550880", "Ashok")
cursor.execute(mysql, value)
mydatabase.commit()
print( "3 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Illisha59550895", "Illisha")
cursor.execute(mysql, value)
mydatabase.commit()
print( "4 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Mira5955082", "Mira")
cursor.execute(mysql, value)
mydatabase.commit()
print( "5 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Sunder5955083", "Sunder")
cursor.execute(mysql, value)
mydatabase.commit()
print( "6 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Vaida5955084", "Vaida")
cursor.execute(mysql, value)
mydatabase.commit()
print( "7 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Suren5955085", "Suren")
cursor.execute(mysql, value)
mydatabase.commit()
print( "8 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Sana5955086", "Sana")
cursor.execute(mysql, value)
mydatabase.commit()
print( "9 record inserted, ID:", cursor.lastrowid)

mysql = "INSERT INTO Userinformation (ScreenName, UserName) VALUE (%s,%s)"
value = ("Krish5955087", "Krish")
cursor.execute(mysql, value)
mydatabase.commit()
print( "10 record inserted, ID:", cursor.lastrowid)
# Out:
# 10 [('Ashok59550880', 'Ashok', 'Houston', 'love', '10', '20', '15', 'https://t.co/7IDoW8Ah9W'), ('Uma59550890', 'Uma', 'Houston', 'I like Houston', '20', '30', '25', 'https://t.co/7IDoW8Ah9W'), ('Illisha59550895', 'Illisha', 'Houston', 'I live in Houston', '10', '20', '10', 'https://t.co/7IDoW8Ah9W'), ('Mira5955082', 'Mira', 'Houston', 'Lovely weather', '5', '10', '15', 'https://t.co/7IDoW8Ah9W'), ('Sunder5955083', 'Sunder', 'Texas', 'Weather is bad in Texas', '55', '100', '10', 'https://t.co/7IDoW8Ah9W'), ('Vaida5955084', 'Vaida', 'Irving', 'Delicious food at Irving', '19', '40', '50', 'https://t.co/7IDoW8Ah9W'), ('Suren5955085', 'Suren', 'Carollton', 'Home sweet home', '90', '29', '10', 'https://t.co/7IDoW8Ah9W'), ('Sana5955086', 'Sana', 'Austin', 'Chill Austin', '70', '17', '20', 'https://t.co/7IDoW8Ah9W'), ('Krish5955087', 'Krish', 'Dallas', 'Today in Dallas', '30', '40', '10', 'https://t.co/7IDoW8Ah9W'), ('Ravi5955088', 'Ravi', 'Denton', 'UNT at Denton', '99', '100', '10', 'http
# ...

# %% [markdown]
# # Question 1.3

# %%
import tweepy 

# For OAUTH we used Consumer keys and access tokens
Consumer_Key = 'oQ4wA3nWX6SrXaK5HdmQBOdw8'
Consumer_Secret = 'XH2usYlx0Kp3gYMJjULZDstQzrQnIDuYNTq6OoJZRKSeVPSYT5'
Access_token ='1192814806681735176-yoniPsr4XMEOdtsphlq9NPKWVfte4K'
Access_token_Secret ='DF12pXdBaKTuvgWDovnApk9EEAh1ibmOvvUaExH40qN6D'

# for OAuth process, the Keys and tokens are uses
auth = tweepy.OAuthHandler(Consumer_Key, Consumer_Secret)

# for setting the access token and access token secret
auth.set_access_token(Access_token, Access_token_Secret)

# creating the object using authentication
api = tweepy.API(auth)

for user in tweepy.Cursor(api.friends, screen_name = "Laxmi").items():
    print('Friend: ' + user.screen_name)
    
for user in tweepy.Cursor(api.followers, screen_name = "Laxmi").items():
    print ('Follower: '+ user.screen_name)
# Out:
# Friend: eroticCJ
# Friend: savannahpeachy
# Friend: TEDDYHAMILTON14
# Friend: GGGBPodcast
# Friend: PepperWinters
# Friend: skye_warren
# Friend: pamgodwinbooks
# Friend: author_ellaj
# Friend: CDReisswriter
# Friend: JAHuss
# Friend: VanessaEVoice
# Friend: xoxoMackenzieC
# Friend: kitswannvo
# Friend: msgracegrant
# Friend: Pippallicious
# Friend: AvaLucasVO
# Friend: auralfixationfb
# Friend: TorThomNarrator
# Friend: SteveWestActor
# Friend: KennicottRoss
# Friend: vikasadam
# Friend: andi_arndt
# Friend: RomanceNarrator
# Friend: ErinMallon
# Friend: TheRealJoeArden
# Friend: ShaneEastReads
# Friend: bryancohenbooks
# Friend: BookFunnel
# Friend: naval
# Friend: BytetheBook
# Friend: Gwen_Hernandez
# Friend: JamiGold
# Friend: daniellesteel
# Friend: _sleach
# Friend: aetherlev
# Friend: KamalaHarris
# Friend: SenKamalaHarris
# Friend: MunroeChristine
# Friend: katiedonelan
# Friend: CarlynAtBookBub
# Friend: iflixletsplay
# Friend: radhikasanghani
# Friend: scottlamb
# ...
